# %%
import pandas as pd

# %%
df = pd.read_csv('test.csv')
df
# Out:
#     ID           HoTen    NgaySinh                 PhongBan  \
# 0  101   Nguyễn Văn An  1990-05-15               Kinh doanh
# 1  102   Trần Thị Bình  1992-08-21                Marketing
# 2  105    Hoàng Văn Em  1993-07-19                 Kỹ thuật
# 3  103    Lê Văn Cường  1988-11-30                 Kỹ thuật
# 4  104   Phạm Thị Dung  1995-02-10                  Nhân sự
# 5  105    Hoàng Văn Em  1993-07-19                 Kỹ thuật
# 6  106  Nguyễn Văn Cao  1990-06-15  Kinh doanh bất động sản
#
#                    ChucVu   Luong
# 0            Trưởng phòng  1500.0
# 1             Chuyên viên  1200.0
# 2    Trưởng nhóm kỹ thuật  2000.0
# 3          Kỹ sư phần mềm  1800.0
# 4  Chuyên viên tuyển dụng  1100.0
# 5    Trưởng nhóm kỹ thuật  2000.0
# 6               Phó phòng     NaN

# %%
#Show 3 firts the rows
df.head(3)
# Out:
#     ID          HoTen    NgaySinh    PhongBan                ChucVu   Luong
# 0  101  Nguyễn Văn An  1990-05-15  Kinh doanh          Trưởng phòng  1500.0
# 1  102  Trần Thị Bình  1992-08-21   Marketing           Chuyên viên  1200.0
# 2  105   Hoàng Văn Em  1993-07-19    Kỹ thuật  Trưởng nhóm kỹ thuật  2000.0

# %%
#Show 3 end the rows
df.tail(3)
# Out:
#     ID           HoTen    NgaySinh                 PhongBan  \
# 4  104   Phạm Thị Dung  1995-02-10                  Nhân sự
# 5  105    Hoàng Văn Em  1993-07-19                 Kỹ thuật
# 6  106  Nguyễn Văn Cao  1990-06-15  Kinh doanh bất động sản
#
#                    ChucVu   Luong
# 4  Chuyên viên tuyển dụng  1100.0
# 5    Trưởng nhóm kỹ thuật  2000.0
# 6               Phó phòng     NaN

# %%
#Show random 3 the rows
df.sample(3)
# Out:
#     ID          HoTen    NgaySinh    PhongBan                ChucVu   Luong
# 0  101  Nguyễn Văn An  1990-05-15  Kinh doanh          Trưởng phòng  1500.0
# 2  105   Hoàng Văn Em  1993-07-19    Kỹ thuật  Trưởng nhóm kỹ thuật  2000.0
# 3  103   Lê Văn Cường  1988-11-30    Kỹ thuật        Kỹ sư phần mềm  1800.0

# %%
#Show the columns and the rows
df.shape
# Out:
# (7, 6)

# %%
#Show information
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7 entries, 0 to 6
# Data columns (total 6 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   ID        7 non-null      int64
#  1   HoTen     7 non-null      object
#  2   NgaySinh  7 non-null      object
#  3   PhongBan  7 non-null      object
#  4   ChucVu    7 non-null      object
#  5   Luong     6 non-null      float64
# dtypes: float64(1), int64(1), object(4)
# memory usage: 468.0+ bytes

# %%
#Show all the row index
df.index
# Out:
# RangeIndex(start=0, stop=7, step=1)

# %%
#Show all the columns index
df.columns
# Out:
# Index(['ID', 'HoTen', 'NgaySinh', 'PhongBan', 'ChucVu', 'Luong'], dtype='object')

# %%
#Set index
df.set_index('HoTen')
df.head()
# Out:
#     ID          HoTen    NgaySinh    PhongBan                  ChucVu   Luong
# 0  101  Nguyễn Văn An  1990-05-15  Kinh doanh            Trưởng phòng  1500.0
# 1  102  Trần Thị Bình  1992-08-21   Marketing             Chuyên viên  1200.0
# 2  105   Hoàng Văn Em  1993-07-19    Kỹ thuật    Trưởng nhóm kỹ thuật  2000.0
# 3  103   Lê Văn Cường  1988-11-30    Kỹ thuật          Kỹ sư phần mềm  1800.0
# 4  104  Phạm Thị Dung  1995-02-10     Nhân sự  Chuyên viên tuyển dụng  1100.0

# %%
#Set index nayf ghi đè bảng
df.set_index('HoTen', inplace=True)
df.head()
# Out:
#                 ID    NgaySinh    PhongBan                  ChucVu   Luong
# HoTen
# Nguyễn Văn An  101  1990-05-15  Kinh doanh            Trưởng phòng  1500.0
# Trần Thị Bình  102  1992-08-21   Marketing             Chuyên viên  1200.0
# Hoàng Văn Em   105  1993-07-19    Kỹ thuật    Trưởng nhóm kỹ thuật  2000.0
# Lê Văn Cường   103  1988-11-30    Kỹ thuật          Kỹ sư phần mềm  1800.0
# Phạm Thị Dung  104  1995-02-10     Nhân sự  Chuyên viên tuyển dụng  1100.0

# %%
df.reset_index(inplace=True)
df.head()
# Out:
#            HoTen   ID    NgaySinh    PhongBan                  ChucVu   Luong
# 0  Nguyễn Văn An  101  1990-05-15  Kinh doanh            Trưởng phòng  1500.0
# 1  Trần Thị Bình  102  1992-08-21   Marketing             Chuyên viên  1200.0
# 2   Hoàng Văn Em  105  1993-07-19    Kỹ thuật    Trưởng nhóm kỹ thuật  2000.0
# 3   Lê Văn Cường  103  1988-11-30    Kỹ thuật          Kỹ sư phần mềm  1800.0
# 4  Phạm Thị Dung  104  1995-02-10     Nhân sự  Chuyên viên tuyển dụng  1100.0

# %%
#Lọc dữ liệu dòng cột index
df.loc[1]
# Out:
# HoTen       Trần Thị Bình
# ID                    102
# NgaySinh       1992-08-21
# PhongBan        Marketing
# ChucVu        Chuyên viên
# Luong              1200.0
# Name: 1, dtype: object

# %%
#Lọc dữ liệu dòng cột index ([1, 2] đang dưới dạng list nên thêm 1 dâuys )
df.loc[[1, 2]]
# Out:
#            HoTen   ID    NgaySinh   PhongBan                ChucVu   Luong
# 1  Trần Thị Bình  102  1992-08-21  Marketing           Chuyên viên  1200.0
# 2   Hoàng Văn Em  105  1993-07-19   Kỹ thuật  Trưởng nhóm kỹ thuật  2000.0

# %%
#Lọc dữ liệu dòng cột index
df.loc[[1, 2], ['NgaySinh', 'PhongBan']]
# Out:
#      NgaySinh   PhongBan
# 1  1992-08-21  Marketing
# 2  1993-07-19   Kỹ thuật

# %%
df.loc[2:4, ['ID','ChucVu']]
# Out:
#     ID                  ChucVu
# 2  105    Trưởng nhóm kỹ thuật
# 3  103          Kỹ sư phần mềm
# 4  104  Chuyên viên tuyển dụng

# %%
df.head()
# Out:
#            HoTen   ID    NgaySinh    PhongBan                  ChucVu   Luong
# 0  Nguyễn Văn An  101  1990-05-15  Kinh doanh            Trưởng phòng  1500.0
# 1  Trần Thị Bình  102  1992-08-21   Marketing             Chuyên viên  1200.0
# 2   Hoàng Văn Em  105  1993-07-19    Kỹ thuật    Trưởng nhóm kỹ thuật  2000.0
# 3   Lê Văn Cường  103  1988-11-30    Kỹ thuật          Kỹ sư phần mềm  1800.0
# 4  Phạm Thị Dung  104  1995-02-10     Nhân sự  Chuyên viên tuyển dụng  1100.0

# %%
df.iloc[2, 1]
# Out:
# np.int64(105)

# %%
# Đếm số lượng danh mục lặp lại
df[['Luong', 'HoTen']].value_counts()
# Mảng tên các danh mục
#df['Luong'].unique()
# Số lượng danh mục
#df['Luong'].value_counts()
# Out:
# Luong   HoTen
# 2000.0  Hoàng Văn Em     2
# 1100.0  Phạm Thị Dung    1
# 1200.0  Trần Thị Bình    1
# 1500.0  Nguyễn Văn An    1
# 1800.0  Lê Văn Cường     1
# Name: count, dtype: int64

# %%
#Đếm số lượng giá trị thiếu trong mỗi cột
df.isnull().sum()
# Out:
# HoTen       0
# ID          0
# NgaySinh    0
# PhongBan    0
# ChucVu      0
# Luong       1
# dtype: int64

# %%
#Thay the gia tri thieu bang mot gia tri cu the
df.fillna(1, inplace=True)

# %%
#Xóa hàng bj trùng
df.drop_duplicates()
# Out:
#             HoTen   ID    NgaySinh                 PhongBan  \
# 0   Nguyễn Văn An  101  1990-05-15               Kinh doanh
# 1   Trần Thị Bình  102  1992-08-21                Marketing
# 2    Hoàng Văn Em  105  1993-07-19                 Kỹ thuật
# 3    Lê Văn Cường  103  1988-11-30                 Kỹ thuật
# 4   Phạm Thị Dung  104  1995-02-10                  Nhân sự
# 6  Nguyễn Văn Cao  106  1990-06-15  Kinh doanh bất động sản
#
#                    ChucVu   Luong
# 0            Trưởng phòng  1500.0
# 1             Chuyên viên  1200.0
# 2    Trưởng nhóm kỹ thuật  2000.0
# 3          Kỹ sư phần mềm  1800.0
# 4  Chuyên viên tuyển dụng  1100.0
# 6               Phó phòng     1.0

# %%
# Đổi tên cột
df.rename(columns={'ID':'IDNV'}, inplace=True)
df.head()
# Out:
#            HoTen  IDNV    NgaySinh    PhongBan                  ChucVu   Luong
# 0  Nguyễn Văn An   101  1990-05-15  Kinh doanh            Trưởng phòng  1500.0
# 1  Trần Thị Bình   102  1992-08-21   Marketing             Chuyên viên  1200.0
# 2   Hoàng Văn Em   105  1993-07-19    Kỹ thuật    Trưởng nhóm kỹ thuật  2000.0
# 3   Lê Văn Cường   103  1988-11-30    Kỹ thuật          Kỹ sư phần mềm  1800.0
# 4  Phạm Thị Dung   104  1995-02-10     Nhân sự  Chuyên viên tuyển dụng  1100.0

# %%
#Show data có điều kiện
df[df['Luong'] > 1500]
# Out:
#           HoTen  IDNV    NgaySinh  PhongBan                ChucVu   Luong
# 2  Hoàng Văn Em   105  1993-07-19  Kỹ thuật  Trưởng nhóm kỹ thuật  2000.0
# 3  Lê Văn Cường   103  1988-11-30  Kỹ thuật        Kỹ sư phần mềm  1800.0
# 5  Hoàng Văn Em   105  1993-07-19  Kỹ thuật  Trưởng nhóm kỹ thuật  2000.0

# %%
#Sắp xếp dữ liệu
df.sort_values('Luong', ascending=True)
# Out:
#             HoTen  IDNV    NgaySinh                 PhongBan  \
# 6  Nguyễn Văn Cao   106  1990-06-15  Kinh doanh bất động sản
# 4   Phạm Thị Dung   104  1995-02-10                  Nhân sự
# 1   Trần Thị Bình   102  1992-08-21                Marketing
# 0   Nguyễn Văn An   101  1990-05-15               Kinh doanh
# 3    Lê Văn Cường   103  1988-11-30                 Kỹ thuật
# 2    Hoàng Văn Em   105  1993-07-19                 Kỹ thuật
# 5    Hoàng Văn Em   105  1993-07-19                 Kỹ thuật
#
#                    ChucVu   Luong
# 6               Phó phòng     1.0
# 4  Chuyên viên tuyển dụng  1100.0
# 1             Chuyên viên  1200.0
# 0            Trưởng phòng  1500.0
# 3          Kỹ sư phần mềm  1800.0
# 2    Trưởng nhóm kỹ thuật  2000.0
# 5    Trưởng nhóm kỹ thuật  2000.0

# %%
#Sort index
df.sort_index()
# Out:
#             HoTen  IDNV    NgaySinh                 PhongBan  \
# 0   Nguyễn Văn An   101  1990-05-15               Kinh doanh
# 1   Trần Thị Bình   102  1992-08-21                Marketing
# 2    Hoàng Văn Em   105  1993-07-19                 Kỹ thuật
# 3    Lê Văn Cường   103  1988-11-30                 Kỹ thuật
# 4   Phạm Thị Dung   104  1995-02-10                  Nhân sự
# 5    Hoàng Văn Em   105  1993-07-19                 Kỹ thuật
# 6  Nguyễn Văn Cao   106  1990-06-15  Kinh doanh bất động sản
#
#                    ChucVu   Luong
# 0            Trưởng phòng  1500.0
# 1             Chuyên viên  1200.0
# 2    Trưởng nhóm kỹ thuật  2000.0
# 3          Kỹ sư phần mềm  1800.0
# 4  Chuyên viên tuyển dụng  1100.0
# 5    Trưởng nhóm kỹ thuật  2000.0
# 6               Phó phòng     1.0

# %%
#Gom nhom sau do thuc hien phep tinh -> tra ve dataFrame
df.groupby('PhongBan')['Luong'].mean()
# Out:
# PhongBan
# Kinh doanh                 1500.000000
# Kinh doanh bất động sản       1.000000
# Kỹ thuật                   1933.333333
# Marketing                  1200.000000
# Nhân sự                    1100.000000
# Name: Luong, dtype: float64
